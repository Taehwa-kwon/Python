# %%
# 누락값 Nan NAN nan

# %%
from numpy import NaN, NAN, nan

# %%
NaN ==True
# Out:
# False

# %%
NaN == False
# Out:
# False

# %%
NaN == 0
# Out:
# False

# %%
NaN == ''
# Out:
# True

# %%
NaN == NaN
# Out:
# False

# %%
NaN == nan
# Out:
# False

# %%
import pandas as pd
pd.isnull(NaN)  #pandas 는 3가지 자료구조를 지원한다 - 1차원 자료구조인 Series, 2차원 자료구조인 DataFrame, 그리고 3차원 자료구조인 Panel
# Out:
# True

# %%
visited = pd.read_csv('../data/survey_visited.csv')
survey = pd.read_csv('../data/survey_survey.csv')

# %%
visited.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ident   8 non-null      int64
#  1   site    8 non-null      object
#  2   dated   7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 320.0+ bytes

# %%
survey.info() #RangeIndex가 21개인데 person 에서 19개니깐 2개가 null이다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   taken    21 non-null     int64
#  1   person   19 non-null     object
#  2   quant    21 non-null     object
#  3   reading  21 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 800.0+ bytes

# %%
#머신러닝 , 립러닝에서 Nan 이나 null값이 있으면 동작을 안하기 때문에 누락값을 처리한다.
# 1. Nan값을 제거한다. (행,컬럼 단위로 제거)
# 2.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-54ff76ffec33> in <module>
# ----> 1 vs.info()
#
# NameError: name 'vs' is not defined

# %%
vs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-20a4108516c6> in <module>
# ----> 1 vs
#
# NameError: name 'vs' is not defined

# %%
gapminder = pd.read_csv('../data/gapminder.tsv', sep='\t')  #sep = 탭으로 나눠진걸 구분해서 가져온다.

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
life_exp = gapminder.groupby(['year'])['lifeExp'].mean()

# %%
life_exp
type(life_exp)
# Out:
# pandas.core.series.Series

# %%
a = list(range(2000,2010))
a
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]

# %%
ebola = pd.read_csv('../data/country_timeseries.csv')

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.shape[0] #몇 행인지 추출가능
# Out:
# 122

# %%
ebola.count() #nan값은 count에서 빠진다.
# Out:
# Date                   122
# Day                    122
# Cases_Guinea            93
# Cases_Liberia           83
# Cases_SierraLeone       87
# Cases_Nigeria           38
# Cases_Senegal           25
# Cases_UnitedStates      18
# Cases_Spain             16
# Cases_Mali              12
# Deaths_Guinea           92
# Deaths_Liberia          81
# Deaths_SierraLeone      87
# Deaths_Nigeria          38
# Deaths_Senegal          22
# Deaths_UnitedStates     18
# Deaths_Spain            16
# Deaths_Mali             12
# dtype: int64

# %%
import numpy as np

# %%
np.count_nonzero(ebola.isnull())
# Out:
# 1214

# %%
ebola.isnull() #null값인 것만 True 로 나온다.
# Out:
#       Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    False  False         False           True              False
# 1    False  False         False           True              False
# 2    False  False         False          False              False
# 3    False  False          True          False               True
# 4    False  False         False          False              False
# ..     ...    ...           ...            ...                ...
# 117  False  False         False          False              False
# 118  False  False         False           True               True
# 119  False  False         False           True               True
# 120  False  False         False           True               True
# 121  False  False         False           True               True
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0             True           True                True         True
# ...

# %%
ebola.Cases_Guinea
# Out:
# 0      2776.0
# 1      2775.0
# 2      2769.0
# 3         NaN
# 4      2730.0
#         ...
# 117     103.0
# 118      86.0
# 119      86.0
# 120      86.0
# 121      49.0
# Name: Cases_Guinea, Length: 122, dtype: float64

# %%
ebola['Cases_Guinea']
# Out:
# 0      2776.0
# 1      2775.0
# 2      2769.0
# 3         NaN
# 4      2730.0
#         ...
# 117     103.0
# 118      86.0
# 119      86.0
# 120      86.0
# 121      49.0
# Name: Cases_Guinea, Length: 122, dtype: float64

# %%
ebola.Cases_Guinea.value_counts(dropna=False).head()  #해당 값을 세는거지
# Out:
# NaN      29
# 86.0      3
# 495.0     2
# 112.0     2
# 390.0     2
# Name: Cases_Guinea, dtype: int64

# %%
ebola.Cases_Guinea.value_counts()
# Out:
# 86.0      3
# 112.0     2
# 390.0     2
# 495.0     2
# 2597.0    1
#          ..
# 235.0     1
# 231.0     1
# 226.0     1
# 224.0     1
# 2776.0    1
# Name: Cases_Guinea, Length: 88, dtype: int64

# %%
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.fillna(0) #NaN값을 0으로 채운다.

# %%
ebola.fillna(method='pad')  #NaN값을 앞에 있는 것 으로 채운다.
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2769.0         8157.0             9722.0
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            8.0                6.0
# 119   3/25/2014    3          86.0            8.0                6.0
# 120   3/24/2014    2          86.0            8.0                6.0
# 121   3/22/2014    0          49.0            8.0                6.0
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.fillna(method='bfill') #NaN값을 뒤에 있는 것 으로 채운다.
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0         8166.0            10030.0
# 1      1/4/2015  288        2775.0         8166.0             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2730.0         8157.0             9633.0
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0             20.0            1.0                 4.0          1.0
# ...

# %%
ebola.shape
# Out:
# (122, 18)

# %%
ebola.dropna()
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 19  11/18/2014  241        2047.0         7082.0             6190.0
#
#     Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 19           20.0            1.0                 4.0          1.0         6.0
#
#     Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 19         1214.0          2963.0              1267.0             8.0
#
#     Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 19             0.0                  1.0           0.0          6.0

# %%
ebola.dropna(subset=['Cases_Liberia']) #특정 컬럼에 Nan값이 있을때만 제거가 가능하다.
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# 5    12/28/2014  281        2706.0         8018.0             9446.0
# 7    12/24/2014  277        2630.0         7977.0             9203.0
# ..          ...  ...           ...            ...                ...
# 113    4/1/2014   10         127.0            8.0                2.0
# 114   3/31/2014    9         122.0            8.0                2.0
# 115   3/29/2014    7         112.0            7.0                NaN
# 116   3/28/2014    6         112.0            3.0                2.0
# 117   3/27/2014    5         103.0            8.0                6.0
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 2              NaN            NaN                 NaN          NaN
# ...
